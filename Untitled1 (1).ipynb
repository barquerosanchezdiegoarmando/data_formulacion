# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
from scipy import stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
import statsmodels.stats.diagnostic as smd
import warnings

warnings.filterwarnings("ignore")
from statsmodels.tsa.api import SimpleExpSmoothing
import warnings
from statsmodels.tools.sm_exceptions import ConvergenceWarning

warnings.filterwarnings("ignore")
warnings.simplefilter("ignore", ConvergenceWarning)
from statsmodels.tsa.api import Holt
from statsmodels.tsa.holtwinters.model import ExponentialSmoothing

import warnings

warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import statsmodels.stats.api as sms
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from statsmodels.tools.tools import add_constant

# To get diferent metric scores
from sklearn import metrics
from sklearn.metrics import accuracy_score, roc_curve, confusion_matrix, roc_auc_score

# %load_ext nb_black

from sklearn.metrics import (
    f1_score,
    accuracy_score,
    recall_score,
    precision_score,
    confusion_matrix,
    roc_auc_score,
    precision_recall_curve,
)
from statsmodels.stats import contingency_tables
from scipy.stats import chi2
import geopandas as gpd
import folium

import webbrowser
from urllib.request import urlopen
import json

# %%
Cons_2003 = pd.read_spss("BD 2003.sav")
Cons_2004 = pd.read_spss("BD 2004.sav")
Cons_2005 = pd.read_spss("BD 2005.sav")
Cons_2006 = pd.read_spss("BD 2006.sav")
Cons_2007 = pd.read_spss("BD 2007.sav")
Cons_2009 = pd.read_spss("BD 2009.sav")
Cons_2010 = pd.read_spss("BD 2010.sav")
Cons_2011 = pd.read_spss("BD 2011.sav")
Cons_2012 = pd.read_spss("BD 2012.sav")
Cons_2013 = pd.read_spss("BD 2013.sav")
Cons_2014 = pd.read_spss("BD 2014.sav")
Cons_2015 = pd.read_spss("BD 2015.sav")
Cons_2016 = pd.read_spss("BD 2016.sav")
Cons_2017 = pd.read_spss("BD 2017.sav")
Cons_2018 = pd.read_spss("INEC BD 2018 Constru.sav")
Cons_2019 = pd.read_spss("INEC BD 2019 Constru.sav")
Cons_2020 = pd.read_spss("INEC BD 2020 Constru.sav")
Cons_2021 = pd.read_spss("PAD-construccion anual 2021.sav")
Cons_2022 = pd.read_spss("Base_Anonimizada2022.sav")

# %% [markdown]
# # 2003_perez_residenciales_2hab

# %%
Cons_2003.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25927 entries, 0 to 25926
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      25927 non-null  float64
#  1   AÑO                25927 non-null  float64
#  2   IMPUNumObras       25927 non-null  float64
#  3   AREA               25927 non-null  float64
#  4   VALOR_OBRA         25927 non-null  float64
#  5   COD_TIPO_PERMISO   25927 non-null  float64
#  6   COD_CLASE_OBRA     25927 non-null  float64
#  7   IMPUPisos          25927 non-null  float64
#  8   IMPUCantViviendas  25927 non-null  float64
#  9   IMPUAposentos      25927 non-null  float64
#  10  IMPUDormitorios    25927 non-null  float64
#  11  IMPUMaterialPiso   25927 non-null  float64
#  12  IMPUMaterialPared  25927 non-null  float64
#  13  IMPUMateriaTecho   25927 non-null  float64
#  14  COD_USO_OBRA       25927 non-null  float64
# ...

# %%
Cons_2003_perez = Cons_2003[Cons_2003["CANTON"] == "Pérez Zeledón"]

# %%
Cons_2003_perez.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 772 entries, 8966 to 25926
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      772 non-null    float64
#  1   AÑO                772 non-null    float64
#  2   IMPUNumObras       772 non-null    float64
#  3   AREA               772 non-null    float64
#  4   VALOR_OBRA         772 non-null    float64
#  5   COD_TIPO_PERMISO   772 non-null    float64
#  6   COD_CLASE_OBRA     772 non-null    float64
#  7   IMPUPisos          772 non-null    float64
#  8   IMPUCantViviendas  772 non-null    float64
#  9   IMPUAposentos      772 non-null    float64
#  10  IMPUDormitorios    772 non-null    float64
#  11  IMPUMaterialPiso   772 non-null    float64
#  12  IMPUMaterialPared  772 non-null    float64
#  13  IMPUMateriaTecho   772 non-null    float64
#  14  COD_USO_OBRA       772 non-null    float64
# ...

# %%
Cons_2003_perez["COD_CLASE_OBRA"].unique()
# Out:
# array([1., 2., 3.])

# %%
Cons_2003_perez_residenciales = Cons_2003_perez[Cons_2003_perez["COD_CLASE_OBRA"] == 1]

# %%
Cons_2003_perez_residenciales_2hab = Cons_2003_perez_residenciales[
    Cons_2003_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2003_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 441 entries, 9586 to 25683
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      441 non-null    float64
#  1   AÑO                441 non-null    float64
#  2   IMPUNumObras       441 non-null    float64
#  3   AREA               441 non-null    float64
#  4   VALOR_OBRA         441 non-null    float64
#  5   COD_TIPO_PERMISO   441 non-null    float64
#  6   COD_CLASE_OBRA     441 non-null    float64
#  7   IMPUPisos          441 non-null    float64
#  8   IMPUCantViviendas  441 non-null    float64
#  9   IMPUAposentos      441 non-null    float64
#  10  IMPUDormitorios    441 non-null    float64
#  11  IMPUMaterialPiso   441 non-null    float64
#  12  IMPUMaterialPared  441 non-null    float64
#  13  IMPUMateriaTecho   441 non-null    float64
#  14  COD_USO_OBRA       441 non-null    float64
# ...

# %%
Cons_2003_perez_residenciales_2hab["Precio"] = Cons_2003_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2004_perez_residenciales_2hab

# %%
Cons_2004.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28560 entries, 0 to 28559
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      28560 non-null  float64
#  1   AÑO                28560 non-null  float64
#  2   IMPUNumObras       28560 non-null  float64
#  3   AREA               28560 non-null  float64
#  4   VALOR_OBRA         28560 non-null  float64
#  5   COD_TIPO_PERMISO   28560 non-null  float64
#  6   COD_CLASE_OBRA     28560 non-null  float64
#  7   IMPUPisos          28560 non-null  float64
#  8   IMPUCantViviendas  28560 non-null  float64
#  9   IMPUAposentos      28560 non-null  float64
#  10  IMPUDormitorios    28560 non-null  float64
#  11  IMPUMaterialPiso   28560 non-null  float64
#  12  IMPUMaterialPared  28560 non-null  float64
#  13  IMPUMateriaTecho   28560 non-null  float64
#  14  COD_USO_OBRA       28560 non-null  float64
# ...

# %%
Cons_2004_perez = Cons_2004[Cons_2004["CANTON"] >= "Pérez Zeledón"]

# %%
Cons_2004_perez.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8836 entries, 0 to 28555
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      8836 non-null   float64
#  1   AÑO                8836 non-null   float64
#  2   IMPUNumObras       8836 non-null   float64
#  3   AREA               8836 non-null   float64
#  4   VALOR_OBRA         8836 non-null   float64
#  5   COD_TIPO_PERMISO   8836 non-null   float64
#  6   COD_CLASE_OBRA     8836 non-null   float64
#  7   IMPUPisos          8836 non-null   float64
#  8   IMPUCantViviendas  8836 non-null   float64
#  9   IMPUAposentos      8836 non-null   float64
#  10  IMPUDormitorios    8836 non-null   float64
#  11  IMPUMaterialPiso   8836 non-null   float64
#  12  IMPUMaterialPared  8836 non-null   float64
#  13  IMPUMateriaTecho   8836 non-null   float64
#  14  COD_USO_OBRA       8836 non-null   float64
# ...

# %%
Cons_2004_perez_residenciales = Cons_2004_perez[Cons_2004_perez["COD_CLASE_OBRA"] == 1]

# %%
Cons_2004_perez_residenciales_2hab = Cons_2004_perez_residenciales[
    Cons_2004_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2004_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5705 entries, 234 to 28529
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      5705 non-null   float64
#  1   AÑO                5705 non-null   float64
#  2   IMPUNumObras       5705 non-null   float64
#  3   AREA               5705 non-null   float64
#  4   VALOR_OBRA         5705 non-null   float64
#  5   COD_TIPO_PERMISO   5705 non-null   float64
#  6   COD_CLASE_OBRA     5705 non-null   float64
#  7   IMPUPisos          5705 non-null   float64
#  8   IMPUCantViviendas  5705 non-null   float64
#  9   IMPUAposentos      5705 non-null   float64
#  10  IMPUDormitorios    5705 non-null   float64
#  11  IMPUMaterialPiso   5705 non-null   float64
#  12  IMPUMaterialPared  5705 non-null   float64
#  13  IMPUMateriaTecho   5705 non-null   float64
#  14  COD_USO_OBRA       5705 non-null   float64
# ...

# %%
Cons_2004_perez_residenciales_2hab["Precio"] = Cons_2004_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2005_perez_residenciales_2hab

# %%
Cons_2005_perez = Cons_2005[Cons_2005["CANTON"] == "Pérez Zeledón"]

# %%
Cons_2004_perez.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8836 entries, 0 to 28555
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      8836 non-null   float64
#  1   AÑO                8836 non-null   float64
#  2   IMPUNumObras       8836 non-null   float64
#  3   AREA               8836 non-null   float64
#  4   VALOR_OBRA         8836 non-null   float64
#  5   COD_TIPO_PERMISO   8836 non-null   float64
#  6   COD_CLASE_OBRA     8836 non-null   float64
#  7   IMPUPisos          8836 non-null   float64
#  8   IMPUCantViviendas  8836 non-null   float64
#  9   IMPUAposentos      8836 non-null   float64
#  10  IMPUDormitorios    8836 non-null   float64
#  11  IMPUMaterialPiso   8836 non-null   float64
#  12  IMPUMaterialPared  8836 non-null   float64
#  13  IMPUMateriaTecho   8836 non-null   float64
#  14  COD_USO_OBRA       8836 non-null   float64
# ...

# %%
Cons_2005_perez_residenciales = Cons_2005_perez[Cons_2005_perez["COD_CLASE_OBRA"] == 1]

# %%
Cons_2005_perez_residenciales_2hab = Cons_2005_perez_residenciales[
    Cons_2005_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2005_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1214 entries, 9576 to 30074
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      1214 non-null   float64
#  1   AÑO                1214 non-null   float64
#  2   IMPUNumObras       1214 non-null   float64
#  3   AREA               1214 non-null   float64
#  4   VALOR_OBRA         1214 non-null   float64
#  5   COD_TIPO_PERMISO   1214 non-null   float64
#  6   COD_CLASE_OBRA     1214 non-null   float64
#  7   IMPUPisos          1214 non-null   float64
#  8   IMPUCantViviendas  1214 non-null   float64
#  9   IMPUAposentos      1214 non-null   float64
#  10  IMPUDormitorios    1214 non-null   float64
#  11  IMPUMaterialPiso   1214 non-null   float64
#  12  IMPUMaterialPared  1214 non-null   float64
#  13  IMPUMateriaTecho   1214 non-null   float64
#  14  COD_USO_OBRA       1214 non-null   float64
# ...

# %%
Cons_2005_perez_residenciales_2hab["Precio"] = Cons_2005_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2006_perez_residenciales_2hab

# %%
Cons_2006_perez = Cons_2006[Cons_2006["CANTON"] == "Pérez Zeledón"]
Cons_2006_perez_residenciales = Cons_2006_perez[Cons_2006_perez["COD_CLASE_OBRA"] == 1]
Cons_2006_perez_residenciales_2hab = Cons_2006_perez_residenciales[
    Cons_2006_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2006_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1177 entries, 2788 to 30823
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      1177 non-null   float64
#  1   AÑO                1177 non-null   float64
#  2   IMPUNumObras       1177 non-null   float64
#  3   AREA               1177 non-null   float64
#  4   VALOR_OBRA         1177 non-null   float64
#  5   COD_TIPO_PERMISO   1177 non-null   float64
#  6   COD_CLASE_OBRA     1177 non-null   float64
#  7   IMPUPisos          1177 non-null   float64
#  8   IMPUCantViviendas  1177 non-null   float64
#  9   IMPUAposentos      1177 non-null   float64
#  10  IMPUDormitorios    1177 non-null   float64
#  11  IMPUMaterialPiso   1177 non-null   float64
#  12  IMPUMaterialPared  1177 non-null   float64
#  13  IMPUMateriaTecho   1177 non-null   float64
#  14  COD_USO_OBRA       1177 non-null   float64
# ...

# %%
Cons_2006_perez_residenciales_2hab["Precio"] = Cons_2006_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2007_perez_residenciales_2hab

# %%
Cons_2007_perez = Cons_2007[Cons_2007["CANTON"] == "Pérez Zeledón"]
Cons_2007_perez_residenciales = Cons_2007_perez[Cons_2007_perez["COD_CLASE_OBRA"] == 1]
Cons_2007_perez_residenciales_2hab = Cons_2007_perez_residenciales[
    Cons_2007_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2007_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1512 entries, 2952 to 35648
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      1512 non-null   float64
#  1   AÑO                1512 non-null   float64
#  2   IMPUNumObras       1512 non-null   float64
#  3   AREA               1512 non-null   float64
#  4   VALOR_OBRA         1512 non-null   float64
#  5   COD_TIPO_PERMISO   1512 non-null   float64
#  6   COD_CLASE_OBRA     1512 non-null   float64
#  7   IMPUPisos          1512 non-null   float64
#  8   IMPUCantViviendas  1512 non-null   float64
#  9   IMPUAposentos      1512 non-null   float64
#  10  IMPUDormitorios    1512 non-null   float64
#  11  IMPUMaterialPiso   1512 non-null   float64
#  12  IMPUMaterialPared  1512 non-null   float64
#  13  IMPUMateriaTecho   1512 non-null   float64
#  14  COD_USO_OBRA       1512 non-null   float64
# ...

# %%
Cons_2007_perez_residenciales_2hab["Precio"] = Cons_2007_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2009_perez_residenciales_2hab

# %%
Cons_2009_perez = Cons_2009[Cons_2009["CANTON"] == "Pérez Zeledón"]
Cons_2009_perez_residenciales = Cons_2009_perez[Cons_2009_perez["COD_CLASE_OBRA"] == 1]
Cons_2009_perez_residenciales_2hab = Cons_2009_perez_residenciales[
    Cons_2009_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2009_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 956 entries, 2248 to 22966
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      956 non-null    float64
#  1   AÑO                956 non-null    float64
#  2   IMPUNumObras       956 non-null    float64
#  3   AREA               956 non-null    float64
#  4   VALOR_OBRA         956 non-null    float64
#  5   COD_TIPO_PERMISO   956 non-null    float64
#  6   COD_CLASE_OBRA     956 non-null    float64
#  7   IMPUPisos          956 non-null    float64
#  8   IMPUCantViviendas  956 non-null    float64
#  9   IMPUAposentos      956 non-null    float64
#  10  IMPUDormitorios    956 non-null    float64
#  11  IMPUMaterialPiso   956 non-null    float64
#  12  IMPUMaterialPared  956 non-null    float64
#  13  IMPUMateriaTecho   956 non-null    float64
#  14  COD_USO_OBRA       956 non-null    float64
# ...

# %%
Cons_2009_perez_residenciales_2hab["Precio"] = Cons_2009_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2010_perez_residenciales_2hab

# %%
Cons_2010_perez = Cons_2010[Cons_2010["CANTON"] == "Pérez Zeledón"]
Cons_2010_perez_residenciales = Cons_2010_perez[Cons_2010_perez["COD_CLASE_OBRA"] == 1]
Cons_2010_perez_residenciales_2hab = Cons_2010_perez_residenciales[
    Cons_2010_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2010_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1002 entries, 11087 to 24960
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      1002 non-null   float64
#  1   AÑO                1002 non-null   float64
#  2   IMPUNumObras       1002 non-null   float64
#  3   AREA               1002 non-null   float64
#  4   VALOR_OBRA         1002 non-null   float64
#  5   COD_TIPO_PERMISO   1002 non-null   float64
#  6   COD_CLASE_OBRA     1002 non-null   float64
#  7   IMPUPisos          1002 non-null   float64
#  8   IMPUCantViviendas  1002 non-null   float64
#  9   IMPUAposentos      1002 non-null   float64
#  10  IMPUDormitorios    1002 non-null   float64
#  11  IMPUMaterialPiso   1002 non-null   float64
#  12  IMPUMaterialPared  1002 non-null   float64
#  13  IMPUMateriaTecho   1002 non-null   float64
#  14  COD_USO_OBRA       1002 non-null   float64
# ...

# %%
Cons_2010_perez_residenciales_2hab["Precio"] = Cons_2010_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2011_perez_residenciales_2hab

# %%
Cons_2011_perez = Cons_2011[Cons_2011["CANTON"] == "Pérez Zeledón"]
Cons_2011_perez_residenciales = Cons_2011_perez[Cons_2011_perez["COD_CLASE_OBRA"] == 1]
Cons_2011_perez_residenciales_2hab = Cons_2011_perez_residenciales[
    Cons_2011_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2011_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 886 entries, 427 to 27330
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      886 non-null    float64
#  1   AÑO                886 non-null    float64
#  2   IMPUNumObras       886 non-null    float64
#  3   AREA               886 non-null    float64
#  4   VALOR_OBRA         886 non-null    float64
#  5   COD_TIPO_PERMISO   886 non-null    float64
#  6   COD_CLASE_OBRA     886 non-null    float64
#  7   IMPUPisos          886 non-null    float64
#  8   IMPUCantViviendas  886 non-null    float64
#  9   IMPUAposentos      886 non-null    float64
#  10  IMPUDormitorios    886 non-null    float64
#  11  IMPUMaterialPiso   886 non-null    float64
#  12  IMPUMaterialPared  886 non-null    float64
#  13  IMPUMateriaTecho   886 non-null    float64
#  14  COD_USO_OBRA       886 non-null    float64
# ...

# %%
Cons_2011_perez_residenciales_2hab["Precio"] = Cons_2011_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2012_perez_residenciales_2hab

# %%
Cons_2012_perez = Cons_2012[Cons_2012["CANTON"] == "Pérez Zeledón"]
Cons_2012_perez_residenciales = Cons_2012_perez[Cons_2012_perez["COD_CLASE_OBRA"] == 1]
Cons_2012_perez_residenciales_2hab = Cons_2012_perez_residenciales[
    Cons_2012_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2012_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 947 entries, 4609 to 24525
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      947 non-null    float64
#  1   AÑO                947 non-null    float64
#  2   IMPUNumObras       947 non-null    float64
#  3   AREA               947 non-null    float64
#  4   VALOR_OBRA         947 non-null    float64
#  5   COD_TIPO_PERMISO   947 non-null    float64
#  6   COD_CLASE_OBRA     947 non-null    float64
#  7   IMPUPisos          947 non-null    float64
#  8   IMPUCantViviendas  947 non-null    float64
#  9   IMPUAposentos      947 non-null    float64
#  10  IMPUDormitorios    947 non-null    float64
#  11  IMPUMaterialPiso   947 non-null    float64
#  12  IMPUMaterialPared  947 non-null    float64
#  13  IMPUMateriaTecho   947 non-null    float64
#  14  COD_USO_OBRA       947 non-null    float64
# ...

# %%
Cons_2012_perez_residenciales_2hab["Precio"] = Cons_2012_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2013_perez_residenciales_2hab

# %%
Cons_2013_perez = Cons_2013[Cons_2013["CANTON"] == "Pérez Zeledón"]
Cons_2013_perez_residenciales = Cons_2013_perez[Cons_2013_perez["COD_CLASE_OBRA"] == 1]
Cons_2013_perez_residenciales_2hab = Cons_2013_perez_residenciales[
    Cons_2013_perez_residenciales["IMPUDormitorios"] >= 2
]

# %%
Cons_2013_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 934 entries, 1210 to 26346
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      934 non-null    float64
#  1   AÑO                934 non-null    float64
#  2   IMPUNumObras       934 non-null    float64
#  3   AREA               934 non-null    float64
#  4   VALOR_OBRA         934 non-null    float64
#  5   COD_TIPO_PERMISO   934 non-null    float64
#  6   COD_CLASE_OBRA     934 non-null    float64
#  7   IMPUPisos          934 non-null    float64
#  8   IMPUCantViviendas  934 non-null    float64
#  9   IMPUAposentos      934 non-null    float64
#  10  IMPUDormitorios    934 non-null    float64
#  11  IMPUMaterialPiso   934 non-null    float64
#  12  IMPUMaterialPared  934 non-null    float64
#  13  IMPUMateriaTecho   934 non-null    float64
#  14  COD_USO_OBRA       934 non-null    float64
# ...

# %%
Cons_2013_perez_residenciales_2hab["Precio"] = Cons_2013_perez_residenciales_2hab[
    "VALOR_OBRA"
]

# %% [markdown]
# # 2014_perez_residenciales_2hab

# %%
Cons_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28731 entries, 0 to 28730
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         28731 non-null  object
#  1   cod_provincia  28731 non-null  float64
#  2   provincia      28731 non-null  object
#  3   id_canton      28731 non-null  float64
#  4   canton         28731 non-null  object
#  5   claper         28731 non-null  object
#  6   claobr         28731 non-null  object
#  7   num_obras      28731 non-null  float64
#  8   arecon         28731 non-null  float64
#  9   numpis         28731 non-null  float64
#  10  numviv         28731 non-null  float64
#  11  numapo         28731 non-null  float64
#  12  numdor         28731 non-null  float64
#  13  valobr         28731 non-null  float64
#  14  matpis         28731 non-null  object
#  15  matpar         28731 non-null  object
#  16  mattec         28731 non-null  object
# ...

# %%
Cons_2014["canton"].unique()
# Out:
# array(['San José', 'Goicoechea', 'Aserrí', 'Moravia', 'Tarrazú',
#        'León Cortés', 'Dota', 'Mora', 'Turrubares', 'Alajuela', 'Naranjo',
#        'Orotina', 'San Mateo', 'Upala', 'Atenas', 'Poás', 'Los Chiles',
#        'Guatuso', 'Cartago', 'La Unión', 'Turrialba', 'El Guarco',
#        'Oreamuno', 'Jiménez', 'Alvarado', 'Acosta', 'Heredia',
#        'Santo Domingo', 'Sarapiquí', 'San Pablo', 'San Isidro',
#        'San Rafael', 'Santa Bárbara', 'Hojancha', 'Santa Cruz',
#        'Abangares', 'Carrillo', 'Tilarán', 'Cañas', 'Garabito',
#        'Puntarenas', 'Buenos Aires', 'Esparza', 'Parrita',
#        'Montes de Oro', 'Aguirre', 'Pococí', 'Guácimo', 'Matina',
#        'Talamanca', 'Limón', 'Siquirres', 'Curridabat', 'Escazú',
#        'Desamparados', 'Puriscal', 'Santa Ana', 'Alajuelita',
#        'Vázquez de Coronado', 'Tibás', 'Montes de Oca', 'Pérez Zeledón',
#        'San Ramón', 'Grecia', 'Palmares', 'San Carlos', 'Zarcero',
# ...

# %%
Cons_2014_perez = Cons_2014[Cons_2014["canton"] == "Pérez Zeledón"]
Cons_2014_perez_residenciales = Cons_2014_perez[Cons_2014_perez["claobr"] == "01"]
Cons_2014_perez_residenciales_2hab = Cons_2014_perez_residenciales[
    Cons_2014_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2014_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 951 entries, 4767 to 25689
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         951 non-null    object
#  1   cod_provincia  951 non-null    float64
#  2   provincia      951 non-null    object
#  3   id_canton      951 non-null    float64
#  4   canton         951 non-null    object
#  5   claper         951 non-null    object
#  6   claobr         951 non-null    object
#  7   num_obras      951 non-null    float64
#  8   arecon         951 non-null    float64
#  9   numpis         951 non-null    float64
#  10  numviv         951 non-null    float64
#  11  numapo         951 non-null    float64
#  12  numdor         951 non-null    float64
#  13  valobr         951 non-null    float64
#  14  matpis         951 non-null    object
#  15  matpar         951 non-null    object
#  16  mattec         951 non-null    object
# ...

# %%
Cons_2014_perez_residenciales_2hab["Precio"] = Cons_2014_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # 2015_perez_residenciales_2hab

# %%
Cons_2015_perez = Cons_2015[Cons_2015["canton"] == "Pérez Zeledón"]
Cons_2015_perez_residenciales = Cons_2015_perez[Cons_2015_perez["claobr"] == "01"]
Cons_2015_perez_residenciales_2hab = Cons_2015_perez_residenciales[
    Cons_2015_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2015_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1073 entries, 3397 to 25562
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         1073 non-null   object
#  1   cod_provincia  1073 non-null   float64
#  2   provincia      1073 non-null   object
#  3   id_canton      1073 non-null   float64
#  4   canton         1073 non-null   object
#  5   claper         1073 non-null   object
#  6   claobr         1073 non-null   object
#  7   num_obras      1073 non-null   float64
#  8   arecon         1073 non-null   float64
#  9   numpis         1073 non-null   float64
#  10  numviv         1073 non-null   float64
#  11  numapo         1073 non-null   float64
#  12  numdor         1073 non-null   float64
#  13  valobr         1073 non-null   float64
#  14  matpis         1073 non-null   object
#  15  matpar         1073 non-null   object
#  16  mattec         1073 non-null   object
# ...

# %%
Cons_2015_perez_residenciales_2hab["Precio"] = Cons_2015_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # 2016_perez_residenciales_2hab

# %%
Cons_2016_perez = Cons_2016[Cons_2016["canton"] == "Pérez Zeledón"]
Cons_2016_perez_residenciales = Cons_2016_perez[Cons_2016_perez["claobr"] == "01"]
Cons_2016_perez_residenciales_2hab = Cons_2016_perez_residenciales[
    Cons_2016_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2016_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1419 entries, 2869 to 28962
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         1419 non-null   object
#  1   cod_provincia  1419 non-null   float64
#  2   provincia      1419 non-null   object
#  3   id_canton      1419 non-null   float64
#  4   canton         1419 non-null   object
#  5   claper         1419 non-null   object
#  6   claobr         1419 non-null   object
#  7   num_obras      1419 non-null   float64
#  8   arecon         1419 non-null   float64
#  9   valobr         1419 non-null   float64
#  10  numpis         1419 non-null   float64
#  11  numviv         1419 non-null   float64
#  12  numapo         1419 non-null   float64
#  13  numdor         1419 non-null   float64
#  14  matpis         1419 non-null   object
#  15  matpar         1419 non-null   object
#  16  mattec         1419 non-null   object
# ...

# %%
Cons_2016_perez_residenciales_2hab["Precio"] = Cons_2016_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # 2017_perez_residenciales_2hab

# %%
Cons_2017_perez = Cons_2017[Cons_2017["canton"] == "Pérez Zeledón"]
Cons_2017_perez_residenciales = Cons_2017_perez[Cons_2017_perez["claobr"] == "01"]
Cons_2017_perez_residenciales_2hab = Cons_2017_perez_residenciales[
    Cons_2017_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2017_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1381 entries, 4113 to 19907
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         1381 non-null   object
#  1   cod_provincia  1381 non-null   float64
#  2   provincia      1381 non-null   object
#  3   id_canton      1381 non-null   float64
#  4   canton         1381 non-null   object
#  5   claper         1381 non-null   object
#  6   claobr         1381 non-null   object
#  7   num_obras      1381 non-null   float64
#  8   arecon         1381 non-null   float64
#  9   valobr         1381 non-null   float64
#  10  numpis         1381 non-null   float64
#  11  numviv         1381 non-null   float64
#  12  numapo         1381 non-null   float64
#  13  numdor         1381 non-null   float64
#  14  matpis         1381 non-null   object
#  15  matpar         1381 non-null   object
#  16  mattec         1381 non-null   object
# ...

# %%
Cons_2017_perez_residenciales_2hab["Precio"] = Cons_2017_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # 2018_perez_residenciales_2hab

# %%
Cons_2018["canton"].unique()
# Out:
# array(['San José', 'Desamparados', 'Mora', 'Montes de Oca', 'Tibás',
#        'Turrubares', 'Pérez Zeledón', 'Goicoechea', 'Santa Ana',
#        'Tarrazú', 'Aserrí', 'Escazú', 'Curridabat', 'Alajuelita',
#        'Acosta', 'Moravia', 'Vázquez de Coronado', 'Dota', 'Puriscal',
#        'León Cortés', 'Atenas', 'Alajuela', 'San Ramón', 'Poás',
#        'Naranjo', 'Palmares', 'Grecia', 'Upala', 'Los Chiles', 'Guatuso',
#        'San Carlos', 'Zarcero', 'Valverde Vega', 'San Mateo', 'Orotina',
#        'Cartago', 'La Unión', 'Paraíso', 'Alvarado', 'Turrialba',
#        'Jiménez', 'Oreamuno', 'El Guarco', 'San Pablo', 'Heredia',
#        'Sarapiquí', 'Flores', 'Barva', 'Santo Domingo', 'Santa Bárbara',
#        'San Rafael', 'San Isidro', 'Belén', 'Santa Cruz', 'Liberia',
#        'Nicoya', 'Carrillo', 'Hojancha', 'La Cruz', 'Tilarán',
#        'Abangares', 'Cañas', 'Bagaces', 'Nandayure', 'Puntarenas',
#        'Buenos Aires', 'Esparza', 'Garabito', 'Osa', 'Montes de Oro',
# ...

# %%
Cons_2018_perez = Cons_2018[Cons_2018["canton"] == "Pérez Zeledón"]
Cons_2018_perez_residenciales = Cons_2018_perez[Cons_2018_perez["claobr"] == 1]
Cons_2018_perez_residenciales_2hab = Cons_2018_perez_residenciales[
    Cons_2018_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2018_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1298 entries, 14 to 3098
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Anoper         1298 non-null   float64
#  1   cod_provincia  1298 non-null   float64
#  2   provincia      1298 non-null   object
#  3   id_canton      1298 non-null   float64
#  4   canton         1298 non-null   object
#  5   claper         1298 non-null   float64
#  6   claobr         1298 non-null   float64
#  7   num_obras      1298 non-null   float64
#  8   arecon         1298 non-null   float64
#  9   valobr         1298 non-null   float64
#  10  numpis         1298 non-null   float64
#  11  numviv         1298 non-null   float64
#  12  numapo         1298 non-null   float64
#  13  numdor         1298 non-null   float64
#  14  matpi          1298 non-null   object
#  15  matpar         1298 non-null   object
#  16  mattec         1298 non-null   object
# ...

# %%
Cons_2018_perez_residenciales_2hab["Precio"] = Cons_2018_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # 2019_perez_residenciales_2hab

# %%
Cons_2019_perez = Cons_2019[Cons_2019["canton"] == "Pérez Zeledón"]
Cons_2019_perez_residenciales = Cons_2019_perez[Cons_2019_perez["claobr"] == 1]
Cons_2019_perez_residenciales_2hab = Cons_2019_perez_residenciales[
    Cons_2019_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2019_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1342 entries, 2850 to 28004
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         1342 non-null   object
#  1   cod_provincia  1342 non-null   category
#  2   provincia      1342 non-null   object
#  3   id_canton      1342 non-null   category
#  4   canton         1342 non-null   object
#  5   claper         1342 non-null   category
#  6   claobr         1342 non-null   float64
#  7   num_obras      1342 non-null   float64
#  8   arecon         1342 non-null   float64
#  9   valobr         1342 non-null   float64
#  10  numpis         1342 non-null   float64
#  11  numviv         1342 non-null   float64
#  12  numapo         1342 non-null   float64
#  13  numdor         1342 non-null   float64
#  14  matpi          1342 non-null   object
#  15  matpar         1342 non-null   object
#  16  mattec         1342 non-null   object
# ...

# %%
Cons_2019_perez_residenciales_2hab["Precio"] = Cons_2019_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # 2020_perez_residenciales_2hab

# %%
Cons_2020_perez = Cons_2020[Cons_2020["canton"] == "Pérez Zeledón"]
Cons_2020_perez_residenciales = Cons_2020_perez[Cons_2020_perez["claobr"] == 1]
Cons_2020_perez_residenciales_2hab = Cons_2020_perez_residenciales[
    Cons_2020_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2020_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1108 entries, 965 to 27247
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         1108 non-null   float64
#  1   cod_provincia  1108 non-null   float64
#  2   provincia      1108 non-null   object
#  3   id_canton      1108 non-null   float64
#  4   canton         1108 non-null   object
#  5   claper         1108 non-null   float64
#  6   claobr         1108 non-null   float64
#  7   num_obras      1108 non-null   float64
#  8   areacon        1108 non-null   float64
#  9   numpis         1108 non-null   float64
#  10  numviv         1108 non-null   float64
#  11  numapo         1108 non-null   float64
#  12  numdor         1108 non-null   float64
#  13  valobr         1108 non-null   float64
#  14  matpi          1108 non-null   float64
#  15  matpar         1108 non-null   float64
#  16  mattec         1108 non-null   float64
# ...

# %%
Cons_2020_perez_residenciales_2hab
# Out:
#        anoper  cod_provincia provincia  id_canton         canton  claper  \
# 965    2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 1087   2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 1090   2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 1251   2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 1252   2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# ...       ...            ...       ...        ...            ...     ...
# 26516  2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 26518  2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 26519  2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 26940  2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
# 27247  2020.0            1.0  San José       19.0  Pérez Zeledón     1.0
#
#        claobr  num_obras  areacon  numpis  numviv  numapo  numdor      valobr  \
# ...

# %%
Cons_2020_perez_residenciales_2hab["Precio"] = Cons_2020_perez_residenciales_2hab[
    "valobr"
]

# %%
Cons_2020_perez_residenciales_2hab["Precio"]
# Out:
# 965      28290912.0
# 1087      8852356.0
# 1090     15846360.0
# 1251      9162668.0
# 1252       325920.0
#             ...
# 26516     7849706.0
# 26518     7253201.0
# 26519    17831262.0
# 26940     7766267.0
# 27247    12299935.0
# Name: Precio, Length: 1108, dtype: float64

# %% [markdown]
# # 2021_perez_residenciales_2hab

# %%
Cons_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37251 entries, 0 to 37250
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         37251 non-null  object
#  1   cod_provincia  37251 non-null  float64
#  2   provincia      37251 non-null  object
#  3   id_canton      37251 non-null  float64
#  4   canton         37251 non-null  object
#  5   claper         37251 non-null  object
#  6   claobr         37251 non-null  object
#  7   num_obras      37251 non-null  float64
#  8   arecon         37251 non-null  float64
#  9   valobr         37251 non-null  float64
#  10  numpis         37251 non-null  float64
#  11  numviv         37251 non-null  float64
#  12  numapo         37251 non-null  float64
#  13  numdor         37251 non-null  float64
#  14  matpi          37251 non-null  object
#  15  matpar         37251 non-null  object
#  16  mattec         37251 non-null  object
# ...

# %%
Cons_2021["canton"].unique()
# Out:
# array(['Santa Ana', 'San Ramón', 'Turrialba', 'El Guarco', 'Belén',
#        'Abangares', 'Pérez Zeledón', 'Escazú', 'Tibás', 'San Rafael',
#        'Tilarán', 'Coto Brus', 'Orotina', 'Mora', 'Acosta', 'Los Chiles',
#        'San Mateo', 'Zarcero', 'Moravia', 'Goicoechea', 'San Pablo',
#        'Santo Domingo', 'San Isidro', 'Alvarado', 'Dota', 'Río Cuarto',
#        'Oreamuno', 'Liberia', 'Nicoya', 'Santa Cruz', 'Carrillo',
#        'La Cruz', 'Puntarenas', 'Limón', 'Pococí', 'Jiménez', 'Barva',
#        'Heredia', 'Valverde Vega', 'Hojancha', 'Siquirres', 'Flores',
#        'Corredores', 'Buenos Aires', 'Sarapiquí', 'Cañas', 'Quepos',
#        'Talamanca', 'Desamparados', 'Puriscal', 'Santa Bárbara',
#        'Alajuela', 'Vázquez de Coronado', 'Nandayure', 'Parrita', 'Upala',
#        'Turrubares', 'Montes de Oro', 'Tarrazú', 'Osa', 'San Carlos',
#        'León Cortés', 'Grecia', 'Alajuelita', 'La Unión', 'Garabito',
# ...

# %%
Cons_2021_perez = Cons_2021[Cons_2021["canton"] == "Pérez Zeledón"]

# %%
Cons_2021_perez_residenciales = Cons_2021_perez[Cons_2021_perez["claobr"] == "01"]
Cons_2021_perez_residenciales_2hab = Cons_2021_perez_residenciales[
    Cons_2021_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2021_perez.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1508 entries, 102 to 37039
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   anoper         1508 non-null   object
#  1   cod_provincia  1508 non-null   float64
#  2   provincia      1508 non-null   object
#  3   id_canton      1508 non-null   float64
#  4   canton         1508 non-null   object
#  5   claper         1508 non-null   object
#  6   claobr         1508 non-null   object
#  7   num_obras      1508 non-null   float64
#  8   arecon         1508 non-null   float64
#  9   valobr         1508 non-null   float64
#  10  numpis         1508 non-null   float64
#  11  numviv         1508 non-null   float64
#  12  numapo         1508 non-null   float64
#  13  numdor         1508 non-null   float64
#  14  matpi          1508 non-null   object
#  15  matpar         1508 non-null   object
#  16  mattec         1508 non-null   object
# ...

# %%
Cons_2021_perez_residenciales_2hab["Precio"] = Cons_2021_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # 2022_perez_residenciales_2hab

# %%
Cons_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37500 entries, 0 to 37499
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anoper        37500 non-null  object
#  1   pro_num_prov  37500 non-null  float64
#  2   pc_num_cant   37500 non-null  object
#  3   claper        37500 non-null  object
#  4   claobr        37500 non-null  object
#  5   num_obras     37500 non-null  float64
#  6   arecon        37500 non-null  float64
#  7   numpis        37500 non-null  float64
#  8   numviv        37500 non-null  float64
#  9   numapo        37500 non-null  float64
#  10  numdor        37500 non-null  float64
#  11  valobr        37500 non-null  float64
#  12  matpis        37500 non-null  object
#  13  matpar        37500 non-null  object
#  14  mattec        37500 non-null  object
#  15  usoobr        37500 non-null  object
#  16  financ        37500 non-null  object
# dtypes: float64(8), object(9)
# ...

# %%
Cons_2022_perez = Cons_2022[Cons_2022["pc_num_cant"] == "119"]
Cons_2022_perez_residenciales = Cons_2022_perez[Cons_2022_perez["claobr"] == "01"]
Cons_2022_perez_residenciales_2hab = Cons_2022_perez_residenciales[
    Cons_2022_perez_residenciales["numdor"] >= 2
]

# %%
Cons_2022_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1016 entries, 1772 to 36975
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anoper        1016 non-null   object
#  1   pro_num_prov  1016 non-null   float64
#  2   pc_num_cant   1016 non-null   object
#  3   claper        1016 non-null   object
#  4   claobr        1016 non-null   object
#  5   num_obras     1016 non-null   float64
#  6   arecon        1016 non-null   float64
#  7   numpis        1016 non-null   float64
#  8   numviv        1016 non-null   float64
#  9   numapo        1016 non-null   float64
#  10  numdor        1016 non-null   float64
#  11  valobr        1016 non-null   float64
#  12  matpis        1016 non-null   object
#  13  matpar        1016 non-null   object
#  14  mattec        1016 non-null   object
#  15  usoobr        1016 non-null   object
#  16  financ        1016 non-null   object
# dtypes: float64(8), object(9)
# ...

# %%
Cons_2022_perez_residenciales_2hab["Precio"] = Cons_2022_perez_residenciales_2hab[
    "valobr"
]

# %% [markdown]
# # Un solo dataframe

# %%
Cons_2003_perez_residenciales_2hab["Año"] = 2003
Cons_2004_perez_residenciales_2hab["Año"] = 2004
Cons_2005_perez_residenciales_2hab["Año"] = 2005
Cons_2006_perez_residenciales_2hab["Año"] = 2006
Cons_2007_perez_residenciales_2hab["Año"] = 2007
Cons_2009_perez_residenciales_2hab["Año"] = 2009
Cons_2010_perez_residenciales_2hab["Año"] = 2010
Cons_2011_perez_residenciales_2hab["Año"] = 2011
Cons_2012_perez_residenciales_2hab["Año"] = 2012
Cons_2013_perez_residenciales_2hab["Año"] = 2013
Cons_2014_perez_residenciales_2hab["Año"] = 2014
Cons_2015_perez_residenciales_2hab["Año"] = 2015
Cons_2016_perez_residenciales_2hab["Año"] = 2016
Cons_2017_perez_residenciales_2hab["Año"] = 2017
Cons_2018_perez_residenciales_2hab["Año"] = 2018
Cons_2019_perez_residenciales_2hab["Año"] = 2019
Cons_2020_perez_residenciales_2hab["Año"] = 2020
Cons_2021_perez_residenciales_2hab["Año"] = 2021
Cons_2022_perez_residenciales_2hab["Año"] = 2022

# %%
precio_2003 = Cons_2003_perez_residenciales_2hab["Precio"].mean()
precio_2004 = Cons_2004_perez_residenciales_2hab["Precio"].mean()
precio_2005 = Cons_2005_perez_residenciales_2hab["Precio"].mean()
precio_2006 = Cons_2006_perez_residenciales_2hab["Precio"].mean()
precio_2007 = Cons_2007_perez_residenciales_2hab["Precio"].mean()
precio_2009 = Cons_2009_perez_residenciales_2hab["Precio"].mean()
precio_2010 = Cons_2010_perez_residenciales_2hab["Precio"].mean()
precio_2011 = Cons_2011_perez_residenciales_2hab["Precio"].mean()
precio_2012 = Cons_2012_perez_residenciales_2hab["Precio"].mean()
precio_2013 = Cons_2013_perez_residenciales_2hab["Precio"].mean()
precio_2014 = Cons_2014_perez_residenciales_2hab["Precio"].mean()
precio_2015 = Cons_2015_perez_residenciales_2hab["Precio"].mean()
precio_2016 = Cons_2016_perez_residenciales_2hab["Precio"].mean()
precio_2017 = Cons_2017_perez_residenciales_2hab["Precio"].mean()
precio_2018 = Cons_2018_perez_residenciales_2hab["Precio"].mean()
precio_2019 = Cons_2019_perez_residenciales_2hab["Precio"].mean()
precio_2020 = Cons_2020_perez_residenciales_2hab["Precio"].mean()
precio_2021 = Cons_2021_perez_residenciales_2hab["Precio"].mean()
precio_2022 = Cons_2022_perez_residenciales_2hab["Precio"].mean()

# %%
precios_mean = pd.DataFrame(
    [
        precio_2003,
        precio_2004,
        precio_2005,
        precio_2006,
        precio_2007,
        precio_2009,
        precio_2010,
        precio_2011,
        precio_2012,
        precio_2013,
        precio_2014,
        precio_2015,
        precio_2016,
        precio_2017,
        precio_2018,
        precio_2019,
        precio_2020,
        precio_2021,
        precio_2022,
    ]
)

# %%
index = pd.Index(sm.tsa.datetools.dates_from_range("2004", "2022"))
precios_mean.set_index(index, inplace=True)

# %%
precios_mean.head()
# Out:
#                        0
# 2004-12-31  5.032990e+06
# 2005-12-31  1.063723e+07
# 2006-12-31  5.633811e+06
# 2007-12-31  7.142051e+06
# 2008-12-31  9.211839e+06

# %%
precios_mean.tail()
# Out:
#                        0
# 2018-12-31  1.285068e+07
# 2019-12-31  1.215449e+08
# 2020-12-31  1.336673e+07
# 2021-12-31  1.627425e+07
# 2022-12-31  1.775494e+07

# %%
precios_mean.mean()
# Out:
# 0    1.732358e+07
# dtype: float64

# %%
concatenated_df = pd.concat(
    [
        Cons_2003_perez_residenciales_2hab,
        Cons_2004_perez_residenciales_2hab,
        Cons_2005_perez_residenciales_2hab,
        Cons_2006_perez_residenciales_2hab,
        Cons_2007_perez_residenciales_2hab,
        Cons_2009_perez_residenciales_2hab,
        Cons_2010_perez_residenciales_2hab,
        Cons_2011_perez_residenciales_2hab,
        Cons_2012_perez_residenciales_2hab,
        Cons_2013_perez_residenciales_2hab,
        Cons_2014_perez_residenciales_2hab,
        Cons_2015_perez_residenciales_2hab,
        Cons_2016_perez_residenciales_2hab,
        Cons_2017_perez_residenciales_2hab,
        Cons_2018_perez_residenciales_2hab,
        Cons_2019_perez_residenciales_2hab,
        Cons_2020_perez_residenciales_2hab,
        Cons_2021_perez_residenciales_2hab,
        Cons_2022_perez_residenciales_2hab,
    ],
    axis=0,
)

# %%
concatenated_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25477 entries, 9586 to 36975
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      14774 non-null  float64
#  1   AÑO                14774 non-null  float64
#  2   IMPUNumObras       14774 non-null  float64
#  3   AREA               14774 non-null  float64
#  4   VALOR_OBRA         14774 non-null  float64
#  5   COD_TIPO_PERMISO   14774 non-null  float64
#  6   COD_CLASE_OBRA     14774 non-null  float64
#  7   IMPUPisos          14774 non-null  float64
#  8   IMPUCantViviendas  14774 non-null  float64
#  9   IMPUAposentos      14774 non-null  float64
#  10  IMPUDormitorios    14774 non-null  float64
#  11  IMPUMaterialPiso   14774 non-null  float64
#  12  IMPUMaterialPared  14774 non-null  float64
#  13  IMPUMateriaTecho   14774 non-null  float64
#  14  COD_USO_OBRA       14774 non-null  float64
# ...

# %%
concatenated_df["numdor"].max()
# Out:
# 12.0

# %% [markdown]
# # Precios

# %% [markdown]
# ## Todos

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter

plt.figure(figsize=(20, 10))
sns.boxplot(data=concatenated_df, x="Año", y="Precio", showfliers=False)
plt.xlabel("Año")
plt.ylabel("Precio")
plt.xticks(rotation=45)
ax = plt.gca()
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(False)
ax.yaxis.set_major_formatter(formatter)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
sns.boxplot(data=concatenated_df, x="Año", y="Precio")
plt.xlabel("Año")
plt.ylabel("Precio")
plt.xticks(rotation=45)
plt.ylim(0, 110000000)
ax = plt.gca()
plt.axhline(y=50000000, color="r", linestyle="--", linewidth=2)
formatter = ScalarFormatter(useMathText=False)
formatter.set_scientific(False)
ax.yaxis.set_major_formatter(formatter)
plt.show()

# %%
concatenated_df[concatenated_df.Precio >= 50000000].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 565 entries, 3276 to 35885
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      238 non-null    float64
#  1   AÑO                238 non-null    float64
#  2   IMPUNumObras       238 non-null    float64
#  3   AREA               238 non-null    float64
#  4   VALOR_OBRA         238 non-null    float64
#  5   COD_TIPO_PERMISO   238 non-null    float64
#  6   COD_CLASE_OBRA     238 non-null    float64
#  7   IMPUPisos          238 non-null    float64
#  8   IMPUCantViviendas  238 non-null    float64
#  9   IMPUAposentos      238 non-null    float64
#  10  IMPUDormitorios    238 non-null    float64
#  11  IMPUMaterialPiso   238 non-null    float64
#  12  IMPUMaterialPared  238 non-null    float64
#  13  IMPUMateriaTecho   238 non-null    float64
#  14  COD_USO_OBRA       238 non-null    float64
# ...

# %% [markdown]
# # Filtro por precio min(50Millones)

# %%
min_50 = concatenated_df[concatenated_df.Precio > 50000000]

# %%
min_50.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 562 entries, 3276 to 35885
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   BOL_ID_BOLETA      238 non-null    float64
#  1   AÑO                238 non-null    float64
#  2   IMPUNumObras       238 non-null    float64
#  3   AREA               238 non-null    float64
#  4   VALOR_OBRA         238 non-null    float64
#  5   COD_TIPO_PERMISO   238 non-null    float64
#  6   COD_CLASE_OBRA     238 non-null    float64
#  7   IMPUPisos          238 non-null    float64
#  8   IMPUCantViviendas  238 non-null    float64
#  9   IMPUAposentos      238 non-null    float64
#  10  IMPUDormitorios    238 non-null    float64
#  11  IMPUMaterialPiso   238 non-null    float64
#  12  IMPUMaterialPared  238 non-null    float64
#  13  IMPUMateriaTecho   238 non-null    float64
#  14  COD_USO_OBRA       238 non-null    float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
sns.boxplot(data=min_50, x="Año", y="Precio")
plt.xlabel("Año")
plt.ylabel("Precio")
plt.ylim(40000000, 220000000)
plt.yticks(
    ticks=[
        40000000,
        60000000,
        80000000,
        100000000,
        120000000,
        140000000,
        160000000,
        180000000,
        200000000,
        220000000,
    ],
    labels=[
        "40M",
        "60M",
        "80M",
        "100M",
        "120M",
        "140M",
        "160M",
        "180M",
        "200M",
        "220M",
    ],
)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Bivariate Analysis 2022

# %%
Cons_2022_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1016 entries, 1772 to 36975
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   anoper        1016 non-null   object
#  1   pro_num_prov  1016 non-null   float64
#  2   pc_num_cant   1016 non-null   object
#  3   claper        1016 non-null   object
#  4   claobr        1016 non-null   object
#  5   num_obras     1016 non-null   float64
#  6   arecon        1016 non-null   float64
#  7   numpis        1016 non-null   float64
#  8   numviv        1016 non-null   float64
#  9   numapo        1016 non-null   float64
#  10  numdor        1016 non-null   float64
#  11  valobr        1016 non-null   float64
#  12  matpis        1016 non-null   object
#  13  matpar        1016 non-null   object
#  14  mattec        1016 non-null   object
#  15  usoobr        1016 non-null   object
#  16  financ        1016 non-null   object
#  17  Precio        1016 non-null   float64
# ...

# %%
import pandas as pd


def get_numeric_columns(df):
    numeric_columns = df.select_dtypes(include=["number"]).columns.tolist()
    return numeric_columns


numeric_columns = get_numeric_columns(Cons_2022_perez_residenciales_2hab)
print(numeric_columns)
# Out:
# ['pro_num_prov', 'num_obras', 'arecon', 'numpis', 'numviv', 'numapo', 'numdor', 'valobr', 'Precio']

# %%
plt.figure(figsize=(10, 5))
sns.heatmap(
    Cons_2022_perez_residenciales_2hab[numeric_columns].corr(),
    annot=True,
    cmap="Spectral",
    vmin=-1,
    vmax=1,
)
plt.show()

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

X = (
    Cons_2022_perez_residenciales_2hab.drop(columns=["valobr", "Precio"])
    .select_dtypes(include="number")
    .fillna(0)
)
y = Cons_2022_perez_residenciales_2hab["valobr"].fillna(0).values.reshape(1, -1)

cos_sim = cosine_similarity(X.T, y)

for i, col in enumerate(X.columns):
    print(f"{col}: {cos_sim[i][0]}")
# Out:
# pro_num_prov: 0.7302407109437328
# num_obras: 0.7651675667809099
# arecon: 0.9775073614521729
# numpis: 0.7961557213468655
# numviv: 0.7651675667809099
# numapo: 0.905065652497596
# numdor: 0.8449913330757933
# Año: 0.7302407109437328

# %%
simulitud_coseno = {
    "arecon": 0.9775073614521729,
    "numpis": 0.7961557213468655,
    "numviv": 0.7651675667809099,
    "numapo": 0.905065652497596,
    "numdor": 0.8449913330757933,
}

# %%
def plot_bar_chart(dictionary):
    keys = list(dictionary.keys())
    values = list(dictionary.values())

    plt.bar(keys, values)
    plt.xlabel("Claves")
    plt.ylabel("Valores")
    plt.xticks(rotation=90)
    plt.show()

# %%
plot_bar_chart(simulitud_coseno)

# %%
Cons_2022_perez_residenciales_2hab["Modelos"] = ""

Cons_2022_perez_residenciales_2hab.loc[
    Cons_2022_perez_residenciales_2hab["Precio"] >= 106000000, "Modelos"
] = "E"
Cons_2022_perez_residenciales_2hab.loc[
    (Cons_2022_perez_residenciales_2hab["Precio"] >= 63000000)
    & (Cons_2022_perez_residenciales_2hab["Modelos"] != "E"),
    "Modelos",
] = "D"
Cons_2022_perez_residenciales_2hab.loc[
    (Cons_2022_perez_residenciales_2hab["Precio"] >= 50500000)
    & (Cons_2022_perez_residenciales_2hab["Modelos"] != "D")
    & (Cons_2022_perez_residenciales_2hab["Modelos"] != "E"),
    "Modelos",
] = "A-B-C"

# %%
Cons_2022_perez_residenciales_2hab.head()
# Out:
#      anoper  pro_num_prov pc_num_cant claper claobr  num_obras  arecon  \
# 1772   2022           1.0         119     01     01        1.0    59.0
# 1857   2022           1.0         119     01     01        1.0    88.0
# 1946   2022           1.0         119     01     01        1.0    43.0
# 1947   2022           1.0         119     01     01        1.0    43.0
# 2110   2022           1.0         119     01     01        1.0    50.0
#
#       numpis  numviv  numapo  numdor      valobr matpis matpar mattec usoobr  \
# 1772     1.0     1.0     5.0     2.0  18272540.0     22     10     01     01
# 1857     1.0     1.0     6.0     3.0  24282317.0     07     01     01     01
# 1946     1.0     1.0     4.0     2.0   7253201.0     07     08     01     01
# 1947     1.0     1.0     4.0     2.0   7253201.0     07     08     01     01
# 2110     1.0     1.0     4.0     2.0   8324372.0     07     08     01     01
#
#      financ      Precio   Año Modelos
# 1772     99  18272540.0  2022
# ...

# %%
Cons_2022_perez_residenciales_2hab["Modelos"].unique()
# Out:
# array(['', 'D', 'A-B-C', 'E'], dtype=object)

# %%
plt.figure(figsize=(20, 10))
sns.pairplot(
    data=Cons_2022_perez_residenciales_2hab[
        [   "Precio",
            "arecon",
            "numpis",
            "numviv",
            "numapo",
            "numdor",
            "Modelos",
        ]
    ],
    hue="Modelos",corner=True
)
plt.show()

# %% [markdown]
# # Precio - Area

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=Cons_2022_perez_residenciales_2hab, x="Precio", y="arecon", hue="Modelos"
)
plt.show()

# %% [markdown]
# # Precio - Número de dormitorios

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=Cons_2022_perez_residenciales_2hab, x="Precio", y="numdor", hue="Modelos"
)
plt.show()

# %% [markdown]
# # Unsupervised Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import warnings

warnings.filterwarnings("ignore")

# %%
Cons_2022_perez_residenciales_2hab[numeric_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1016 entries, 1772 to 36975
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pro_num_prov  1016 non-null   float64
#  1   num_obras     1016 non-null   float64
#  2   arecon        1016 non-null   float64
#  3   numpis        1016 non-null   float64
#  4   numviv        1016 non-null   float64
#  5   numapo        1016 non-null   float64
#  6   numdor        1016 non-null   float64
#  7   valobr        1016 non-null   float64
#  8   Precio        1016 non-null   float64
# dtypes: float64(9)
# memory usage: 79.4 KB

# %%
numerical_columns = Cons_2022_perez_residenciales_2hab.select_dtypes(
    include="number"
).columns.tolist()
print(numerical_columns)
# Out:
# ['pro_num_prov', 'num_obras', 'arecon', 'numpis', 'numviv', 'numapo', 'numdor', 'valobr', 'Precio']

# %%
scaler = StandardScaler()
subset = Cons_2022_perez_residenciales_2hab[
    [
        "arecon",
        "numpis",
        "numviv",
        "numapo",
        "numdor",
        "valobr",
    ]
].copy()
subset_scaled = scaler.fit_transform(subset)

# %%
subset_scaled_df = pd.DataFrame(subset_scaled, columns=subset.columns)

# %%
subset_scaled_df
# Out:
#         arecon    numpis    numviv    numapo    numdor    valobr
# 0    -0.244211 -0.294424 -0.133996 -0.113414 -0.556806  0.031160
# 1     0.309923 -0.294424 -0.133996  0.347500  0.686524  0.392956
# 2    -0.549940 -0.294424 -0.133996 -0.574328 -0.556806 -0.632218
# 3    -0.549940 -0.294424 -0.133996 -0.574328 -0.556806 -0.632218
# 4    -0.416183 -0.294424 -0.133996 -0.574328 -0.556806 -0.567732
# ...        ...       ...       ...       ...       ...       ...
# 1011 -0.435291 -0.294424 -0.133996 -0.574328 -0.556806 -0.591560
# 1012  0.042410 -0.294424 -0.133996  0.347500  0.686524  0.222292
# 1013  2.125189 -0.294424 -0.133996  1.269329  0.686524  1.774880
# 1014 -0.511724 -0.294424 -0.133996 -0.574328 -0.556806 -0.580511
# 1015 -0.377967 -0.294424 -0.133996 -0.574328 -0.556806 -0.489869
#
# [1016 rows x 6 columns]

# %% [markdown]
# ## Euclidean

# %%
from scipy.spatial.distance import cdist
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

# %%
clusters = range(1, 9)
meanDistortions = []

for k in clusters:
    model = KMeans(n_clusters=k)
    model.fit(subset_scaled_df)
    prediction = model.predict(subset_scaled_df)
    distortion = (
        sum(
            np.min(cdist(subset_scaled_df, model.cluster_centers_, "euclidean"), axis=1)
        )
        / subset_scaled_df.shape[0]
    )

    meanDistortions.append(distortion)

    print("Number of Clusters:", k, "\tAverage Distortion:", distortion)

plt.plot(clusters, meanDistortions, "bx-")
plt.xlabel("k")
plt.ylabel("Average distortion")
plt.title("Selecting k with the Elbow Method")
plt.show()
# Out:
# Number of Clusters: 1 	Average Distortion: 1.6412139113529505
# Number of Clusters: 2 	Average Distortion: 1.2700311998777796
# Number of Clusters: 3 	Average Distortion: 1.1388036992209056
# Number of Clusters: 4 	Average Distortion: 0.7026077043201392
# Number of Clusters: 5 	Average Distortion: 0.5690007600075082
# Number of Clusters: 6 	Average Distortion: 0.5342892382385709
# Number of Clusters: 7 	Average Distortion: 0.5108384567296902
# Number of Clusters: 8 	Average Distortion: 0.47237106493541986

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(subset_scaled_df)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
Cons_2022_perez_residenciales_2hab["K_means_segments"] = kmeans.labels_
subset_scaled_df["K_means_segments"] = kmeans.labels_

# %%
cluster_profile = Cons_2022_perez_residenciales_2hab.groupby("K_means_segments").mean()

# %%
cluster_profile["count_in_each_segments"] = (
    Cons_2022_perez_residenciales_2hab.groupby("K_means_segments")["Precio"]
    .count()
    .values
)

# %%
cluster_profile.style.highlight_max(color="lightgreen", axis=0)
# Out:
# <style type="text/css">
# #T_c2ec8_row0_col0, #T_c2ec8_row0_col1, #T_c2ec8_row0_col2, #T_c2ec8_row0_col3, #T_c2ec8_row0_col4, #T_c2ec8_row0_col12, #T_c2ec8_row0_col13, #T_c2ec8_row0_col14, #T_c2ec8_row0_col15, #T_c2ec8_row0_col16, #T_c2ec8_row0_col18, #T_c2ec8_row1_col1, #T_c2ec8_row1_col6, #T_c2ec8_row2_col1, #T_c2ec8_row2_col5, #T_c2ec8_row2_col7, #T_c2ec8_row2_col8, #T_c2ec8_row2_col9, #T_c2ec8_row2_col10, #T_c2ec8_row2_col11, #T_c2ec8_row2_col17, #T_c2ec8_row3_col0, #T_c2ec8_row3_col1, #T_c2ec8_row3_col2, #T_c2ec8_row3_col3, #T_c2ec8_row3_col4, #T_c2ec8_row3_col12, #T_c2ec8_row3_col13, #T_c2ec8_row3_col14, #T_c2ec8_row3_col15, #T_c2ec8_row3_col16 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c2ec8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c2ec8_level0_col0" class="col_heading level0 col0" >anoper</th>
#       <th id="T_c2ec8_level0_col1" class="col_heading level0 col1" >pro_num_prov</th>
# ...

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=Cons_2022_perez_residenciales_2hab,
    x="Precio",
    y="arecon",
    hue="K_means_segments",
)
plt.show()

# %%
from sklearn.metrics import calinski_harabasz_score

ch_score = calinski_harabasz_score(
    Cons_2022_perez_residenciales_2hab,
    Cons_2022_perez_residenciales_2hab["K_means_segments"],
)

print("Calinski-Harabasz Score:", ch_score)
# Out:
# Calinski-Harabasz Score: 951.1276104112088

# %% [markdown]
# # Manhattan

# %%
clusters = range(1, 9)
meanDistortions = []

for k in clusters:
    model = KMeans(n_clusters=k)
    model.fit(subset_scaled_df)
    prediction = model.predict(subset_scaled_df)
    distortion = (
        sum(
            np.min(cdist(subset_scaled_df, model.cluster_centers_, "cityblock"), axis=1)
        )
        / subset_scaled_df.shape[0]
    )

    meanDistortions.append(distortion)

    print("Number of Clusters:", k, "\tAverage Distortion:", distortion)

plt.plot(clusters, meanDistortions, "bx-")
plt.xlabel("k")
plt.ylabel("Average distortion")
plt.title("Selecting k with the Elbow Method")
plt.show()
# Out:
# Number of Clusters: 1 	Average Distortion: 4.704471848298284
# Number of Clusters: 2 	Average Distortion: 2.242755585932653
# Number of Clusters: 3 	Average Distortion: 1.3725989801660978
# Number of Clusters: 4 	Average Distortion: 1.2579322255518466
# Number of Clusters: 5 	Average Distortion: 1.0417245122052274
# Number of Clusters: 6 	Average Distortion: 0.9384755486467051
# Number of Clusters: 7 	Average Distortion: 0.854353538033737
# Number of Clusters: 8 	Average Distortion: 0.7875030575276475

# %%
distances = cdist(subset_scaled, subset_scaled, metric="cityblock")
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(distances)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
Cons_2022_perez_residenciales_2hab["K_means_segments"] = kmeans.labels_
subset_scaled_df["K_means_segments"] = kmeans.labels_

# %%
cluster_profile = Cons_2022_perez_residenciales_2hab.groupby("K_means_segments").mean()

# %%
cluster_profile["count_in_each_segments"] = (
    Cons_2022_perez_residenciales_2hab.groupby("K_means_segments")["Precio"]
    .count()
    .values
)

# %%
cluster_profile.style.highlight_max(color="lightgreen", axis=0)
# Out:
# <style type="text/css">
# #T_94469_row0_col0, #T_94469_row0_col1, #T_94469_row0_col2, #T_94469_row0_col3, #T_94469_row0_col4, #T_94469_row0_col12, #T_94469_row0_col13, #T_94469_row0_col14, #T_94469_row0_col15, #T_94469_row0_col16, #T_94469_row0_col18, #T_94469_row1_col1, #T_94469_row1_col5, #T_94469_row1_col6, #T_94469_row1_col7, #T_94469_row1_col8, #T_94469_row1_col9, #T_94469_row1_col10, #T_94469_row1_col11, #T_94469_row1_col17, #T_94469_row2_col0, #T_94469_row2_col1, #T_94469_row2_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_94469">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94469_level0_col0" class="col_heading level0 col0" >anoper</th>
#       <th id="T_94469_level0_col1" class="col_heading level0 col1" >pro_num_prov</th>
#       <th id="T_94469_level0_col2" class="col_heading level0 col2" >pc_num_cant</th>
#       <th id="T_94469_level0_col3" class="col_heading level0 col3" >claper</th>
# ...

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=Cons_2022_perez_residenciales_2hab,
    x="Precio",
    y="arecon",
    hue="K_means_segments",
)
plt.ticklabel_format(style="plain", axis="x")
plt.show()

# %%
from sklearn.metrics import calinski_harabasz_score

ch_score = calinski_harabasz_score(
    Cons_2022_perez_residenciales_2hab,
    Cons_2022_perez_residenciales_2hab["K_means_segments"],
)

print("Calinski-Harabasz Score:", ch_score)
# Out:
# Calinski-Harabasz Score: 1035.0762054995107

# %% [markdown]
# ## Chebyshev

# %%
clusters = range(1, 9)
meanDistortions = []

for k in clusters:
    model = KMeans(n_clusters=k)
    model.fit(subset_scaled_df)
    prediction = model.predict(subset_scaled_df)
    distortion = (
        np.mean(
            np.min(cdist(subset_scaled_df, model.cluster_centers_, "chebyshev"), axis=1)
        )
    )

    meanDistortions.append(distortion)

    print("Number of Clusters:", k, "\tAverage Distortion:", distortion)

plt.plot(clusters, meanDistortions, "bx-")
plt.xlabel("k")
plt.ylabel("Average distortion")
plt.title("Selecting k with the Elbow Method")
plt.show()
# Out:
# Number of Clusters: 1 	Average Distortion: 1.0584240964768543
# Number of Clusters: 2 	Average Distortion: 0.7937150537489822
# Number of Clusters: 3 	Average Distortion: 0.7597274073893711
# Number of Clusters: 4 	Average Distortion: 0.5199176249561643
# Number of Clusters: 5 	Average Distortion: 0.46451057052236233
# Number of Clusters: 6 	Average Distortion: 0.4074158064247703
# Number of Clusters: 7 	Average Distortion: 0.38339861372675016
# Number of Clusters: 8 	Average Distortion: 0.37116886143411687

# %%
distances = cdist(subset_scaled, subset_scaled, metric="chebyshev")
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(distances)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
Cons_2022_perez_residenciales_2hab["K_means_segments"] = kmeans.labels_
subset_scaled_df["K_means_segments"] = kmeans.labels_

# %%
cluster_profile = Cons_2022_perez_residenciales_2hab.groupby("K_means_segments").mean()

# %%
cluster_profile["count_in_each_segments"] = (
    Cons_2022_perez_residenciales_2hab.groupby("K_means_segments")["Precio"]
    .count()
    .values
)

# %%
cluster_profile.style.highlight_max(color="lightgreen", axis=0)
# Out:
# <style type="text/css">
# #T_0c7e4_row0_col0, #T_0c7e4_row0_col1, #T_0c7e4_row0_col2, #T_0c7e4_row0_col3, #T_0c7e4_row0_col4, #T_0c7e4_row0_col12, #T_0c7e4_row0_col13, #T_0c7e4_row0_col14, #T_0c7e4_row0_col15, #T_0c7e4_row0_col16, #T_0c7e4_row0_col18, #T_0c7e4_row1_col0, #T_0c7e4_row1_col1, #T_0c7e4_row1_col2, #T_0c7e4_row1_col5, #T_0c7e4_row1_col6, #T_0c7e4_row1_col7, #T_0c7e4_row1_col8, #T_0c7e4_row1_col9, #T_0c7e4_row1_col10, #T_0c7e4_row1_col11, #T_0c7e4_row1_col17 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0c7e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c7e4_level0_col0" class="col_heading level0 col0" >anoper</th>
#       <th id="T_0c7e4_level0_col1" class="col_heading level0 col1" >pro_num_prov</th>
#       <th id="T_0c7e4_level0_col2" class="col_heading level0 col2" >pc_num_cant</th>
#       <th id="T_0c7e4_level0_col3" class="col_heading level0 col3" >claper</th>
# ...

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=Cons_2022_perez_residenciales_2hab,
    x="Precio",
    y="arecon",
    hue="K_means_segments",
)
plt.show()

# %%
from sklearn.metrics import calinski_harabasz_score

ch_score = calinski_harabasz_score(
    Cons_2022_perez_residenciales_2hab,
    Cons_2022_perez_residenciales_2hab["K_means_segments"],
)

print("Calinski-Harabasz Score:", ch_score)
# Out:
# Calinski-Harabasz Score: 835.1819631494834

# %% [markdown]
# ## Mahalonobis

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import mahalanobis
import numpy as np
import matplotlib.pyplot as plt

# %%
meanDistortions = []

clusters = range(1, 9)


cov_inv = np.linalg.inv(np.cov(subset_scaled_df, rowvar=False))

subset_scaled_array = subset_scaled_df.to_numpy()


for k in clusters:
    model = KMeans(n_clusters=k)

    model.fit(subset_scaled_array)

    mahalanobis_dist = np.array(
        [
            [mahalanobis(point, model.cluster_centers_[i], cov_inv) for i in range(k)]
            for point in subset_scaled_array
        ]
    )

    distortion = np.mean(np.min(mahalanobis_dist, axis=1))

    meanDistortions.append(distortion)

    print("Number of Clusters:", k, "\tAverage Distortion:", distortion)

plt.plot(clusters, meanDistortions, "bx-")
plt.xlabel("k")
plt.ylabel("Average distortion")
plt.title("Selecting k with the Elbow Method")
plt.show()
# Out:
# Number of Clusters: 1 	Average Distortion: 1.8051713830546607
# Number of Clusters: 2 	Average Distortion: 1.6912453803082308
# Number of Clusters: 3 	Average Distortion: 1.611310785841158
# Number of Clusters: 4 	Average Distortion: 1.2844169420163738
# Number of Clusters: 5 	Average Distortion: 1.2035256154523084
# Number of Clusters: 6 	Average Distortion: 1.1703284384005086
# Number of Clusters: 7 	Average Distortion: 1.1305433913417817
# Number of Clusters: 8 	Average Distortion: 1.0603800423863754

# %%
distances = cdist(subset_scaled, subset_scaled, metric="mahalanobis")
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(distances)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
Cons_2022_perez_residenciales_2hab["K_means_segments"] = kmeans.labels_
subset_scaled_df["K_means_segments"] = kmeans.labels_

# %%
cluster_profile = Cons_2022_perez_residenciales_2hab.groupby("K_means_segments").mean()

# %%
cluster_profile["count_in_each_segments"] = (
    Cons_2022_perez_residenciales_2hab.groupby("K_means_segments")["Precio"]
    .count()
    .values
)

# %%
cluster_profile.style.highlight_max(color="lightgreen", axis=0)
# Out:
# <style type="text/css">
# #T_0949f_row0_col0, #T_0949f_row0_col1, #T_0949f_row0_col2, #T_0949f_row0_col3, #T_0949f_row0_col4, #T_0949f_row0_col12, #T_0949f_row0_col13, #T_0949f_row0_col14, #T_0949f_row0_col15, #T_0949f_row0_col16, #T_0949f_row0_col18, #T_0949f_row1_col1, #T_0949f_row1_col5, #T_0949f_row1_col6, #T_0949f_row1_col7, #T_0949f_row1_col8, #T_0949f_row1_col9, #T_0949f_row1_col10, #T_0949f_row1_col11, #T_0949f_row1_col17, #T_0949f_row2_col0, #T_0949f_row2_col1, #T_0949f_row3_col0, #T_0949f_row3_col1, #T_0949f_row3_col2, #T_0949f_row3_col3, #T_0949f_row3_col4, #T_0949f_row3_col12, #T_0949f_row3_col13, #T_0949f_row3_col14, #T_0949f_row3_col15, #T_0949f_row3_col16 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0949f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0949f_level0_col0" class="col_heading level0 col0" >anoper</th>
#       <th id="T_0949f_level0_col1" class="col_heading level0 col1" >pro_num_prov</th>
# ...

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=Cons_2022_perez_residenciales_2hab,
    x="Precio",
    y="arecon",
    hue="K_means_segments",
)
plt.show()

# %%
from sklearn.metrics import calinski_harabasz_score

ch_score = calinski_harabasz_score(
    Cons_2022_perez_residenciales_2hab,
    Cons_2022_perez_residenciales_2hab["K_means_segments"],
)

print("Calinski-Harabasz Score:", ch_score)
# Out:
# Calinski-Harabasz Score: 717.0575209750339

# %% [markdown]
# # Best Clustering

# %%
distances = cdist(subset_scaled, subset_scaled, metric="cityblock")
kmeans = KMeans(n_clusters=3, random_state=0)
kmeans.fit(distances)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
Cons_2022_perez_residenciales_2hab["K_means_segments"] = kmeans.labels_
subset_scaled_df["K_means_segments"] = kmeans.labels_

# %%
Cons_2022_perez_residenciales_2hab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1016 entries, 1772 to 36975
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anoper            1016 non-null   object
#  1   pro_num_prov      1016 non-null   float64
#  2   pc_num_cant       1016 non-null   object
#  3   claper            1016 non-null   object
#  4   claobr            1016 non-null   object
#  5   num_obras         1016 non-null   float64
#  6   arecon            1016 non-null   float64
#  7   numpis            1016 non-null   float64
#  8   numviv            1016 non-null   float64
#  9   numapo            1016 non-null   float64
#  10  numdor            1016 non-null   float64
#  11  valobr            1016 non-null   float64
#  12  matpis            1016 non-null   object
#  13  matpar            1016 non-null   object
#  14  mattec            1016 non-null   object
#  15  usoobr            1016 non-null   object
# ...

# %%
cluster_profile = Cons_2022_perez_residenciales_2hab.groupby("K_means_segments").mean()

# %%
cluster_profile["count_in_each_segments"] = (
    Cons_2022_perez_residenciales_2hab.groupby("K_means_segments")["Precio"]
    .count()
    .values
)

# %%
from sklearn.metrics import calinski_harabasz_score

ch_score = calinski_harabasz_score(
    Cons_2022_perez_residenciales_2hab,
    Cons_2022_perez_residenciales_2hab["K_means_segments"],
)

print("Calinski-Harabasz Score:", ch_score)
# Out:
# Calinski-Harabasz Score: 1035.0762054995107

# %% [markdown]
# ## Representación Gráfica

# %% [markdown]
# ### Precio, M2
# - Modelo A: (50.603,106.88)
# - Modelo B: (52.328,109.88)
# - Modelo C: (50.603,106.88)
# - Modelo D: (63.237,127.25)
# - Modelo E1:(106.758, 175.76)
# - Modelo E1:(106.758, 175.76)
# - Modelo E2:(106.758, 181.98)

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=Cons_2022_perez_residenciales_2hab,
    x="Precio",
    y="arecon",
    hue="K_means_segments",
)
plt.ticklabel_format(style="plain", axis="x")
plt.text(47000000, 300, "Modelos A-B-C", fontsize=12, color="red")
plt.text(80000000, 360, "Modelos D", fontsize=12, color="red")
plt.text(113000000, 425, "Modelos E", fontsize=12, color="red")
plt.axvline(x=45000000, color="indianred", linestyle="--", linewidth=2, label="Min(P)")
plt.axvline(x=60000000, color="indianred", linestyle="--", linewidth=2, label="Mean(P)")
plt.axvline(x=106000000, color="indianred", linestyle="--", linewidth=2, label="Max(P)")
# Modelos
plt.plot(52328000, 109.88, "bo", label="B")
plt.plot(50603000, 106.88, "go", label="A-C")
plt.plot(63237206, 127.25, "co", label="D")
plt.plot(106758206, 175.76, "ro", label="E1")
plt.plot(106758206, 182, "ro", label="E2")
plt.legend()
plt.show()

# %%
Cons_2022_perez_residenciales_2hab = Cons_2022_perez_residenciales_2hab[
    [
        "arecon",
        "numpis",
        "numviv",
        "numapo",
        "numdor",
        "valobr",
        "K_means_segments",
        "Precio",
    ]
]

# %%
Cons_2022_perez_residenciales_2hab_segment2 = Cons_2022_perez_residenciales_2hab[
    Cons_2022_perez_residenciales_2hab["K_means_segments"] == 2
]

# %%
sns.boxplot(data=Cons_2022_perez_residenciales_2hab_segment2, x="Precio")

# Get the current Axes instance
ax = plt.gca()

# Format tick labels on the x-axis to remove scientific notation
tick_labels = [f"{tick:.0f}" for tick in ax.get_xticks()]
ax.set_xticklabels(tick_labels)

# Show the plot
plt.show()

# %% [markdown]
# ## Estadísticos del cluster 2 ( Modelos D-E )

# %%
Cons_2022_perez_residenciales_2hab[
    Cons_2022_perez_residenciales_2hab["K_means_segments"] == 2
].describe()
# Out:
#            arecon      numpis      numviv      numapo      numdor  \
# count  124.000000  124.000000  124.000000  124.000000  124.000000
# mean   148.741935    1.500000    1.088710    8.096774    3.137097
# std     56.484241    0.502028    0.312662    2.250273    0.575018
# min     44.000000    1.000000    1.000000    4.000000    2.000000
# 25%    110.750000    1.000000    1.000000    6.000000    3.000000
# 50%    140.000000    1.500000    1.000000    7.000000    3.000000
# 75%    181.250000    2.000000    1.000000    8.000000    3.000000
# max    340.000000    2.000000    3.000000   12.000000    6.000000
#
#              valobr  K_means_segments        Precio
# count  1.240000e+02             124.0  1.240000e+02
# mean   4.166725e+07               2.0  4.166725e+07
# std    1.658621e+07               0.0  1.658621e+07
# min    5.903251e+06               2.0  5.903251e+06
# 25%    2.925232e+07               2.0  2.925232e+07
# 50%    3.961866e+07               2.0  3.961866e+07
# ...

# %% [markdown]
# ## Estadísticos del cluster 1 ( Modelos A-B-C )

# %%
Cons_2022_perez_residenciales_2hab[
    Cons_2022_perez_residenciales_2hab["K_means_segments"] == 1
].describe()
# Out:
#            arecon     numpis     numviv     numapo     numdor        valobr  \
# count   23.000000  23.000000  23.000000  23.000000  23.000000  2.300000e+01
# mean   273.347826   1.869565   2.391304  14.086957   5.826087  8.190057e+07
# std     97.859644   0.457697   1.559112   3.691674   2.103075  2.920440e+07
# min    130.000000   1.000000   1.000000  12.000000   3.000000  3.353979e+07
# 25%    209.000000   2.000000   1.000000  12.000000   4.000000  6.513705e+07
# 50%    242.000000   2.000000   2.000000  12.000000   6.000000  7.627505e+07
# 75%    364.500000   2.000000   3.500000  15.000000   6.000000  1.077202e+08
# max    436.000000   3.000000   6.000000  24.000000  12.000000  1.282372e+08
#
#        K_means_segments        Precio
# count              23.0  2.300000e+01
# mean                1.0  8.190057e+07
# std                 0.0  2.920440e+07
# min                 1.0  3.353979e+07
# 25%                 1.0  6.513705e+07
# 50%                 1.0  7.627505e+07
# ...

# %% [markdown]
# # Clusters

# %%
data = {
    "1": [
        273.347826,
        1.869565,
        2.391304,
        14.086957,
        5.826087,
        8.190057e07,
    ],
    "2": [148.741935, 1.500000, 1.088710, 8.096774, 3.137097, 4.166725e07],
}
df_cluster_mean = pd.DataFrame(data)

# %%
df_cluster_mean = df_cluster_mean.T

# %%
df_cluster_mean.columns = [
    "arecon",
    "numpis",
    "numviv",
    "numapo",
    "numdor",
    "Precio",
]

# %%
df_cluster_mean
# Out:
#        arecon    numpis    numviv     numapo    numdor      Precio
# 1  273.347826  1.869565  2.391304  14.086957  5.826087  81900570.0
# 2  148.741935  1.500000  1.088710   8.096774  3.137097  41667250.0

# %%
import matplotlib.pyplot as plt

# Assuming df_cluster_mean is your DataFrame

# Set the index as the x-axis labels
x_labels = df_cluster_mean.drop("Precio", axis=1).index

# Set the width of the bars
bar_width = 0.35

# Set the positions for the bars
positions = range(len(df_cluster_mean.drop("Precio", axis=1).columns))

# Iterate over the rows of the DataFrame
for i, (_, row) in enumerate(df_cluster_mean.drop("Precio", axis=1).iterrows()):
    bars = plt.bar([pos + i * bar_width for pos in positions], row.values, bar_width, label=f'Cluster {i+1}')
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width() / 2, height, '%d' % int(height), ha='center', va='bottom')

plt.xlabel('Exógenas')
plt.ylabel('Valores')
plt.xticks([pos + bar_width for pos in positions], df_cluster_mean.drop("Precio", axis=1).columns)
plt.legend()

plt.show()

# %%
sns.barplot(data=df_cluster_mean, x=df_cluster_mean.index, y="arecon")
# Out:
# <Axes: ylabel='arecon'>

# %%
sns.barplot(data=df_cluster_mean, x=df_cluster_mean.index, y="numpis")
# Out:
# <Axes: ylabel='numpis'>

# %%
sns.barplot(data=df_cluster_mean, x=df_cluster_mean.index, y="numviv")
# Out:
# <Axes: ylabel='numviv'>

# %%
sns.barplot(data=df_cluster_mean, x=df_cluster_mean.index, y="numapo")
# Out:
# <Axes: ylabel='numapo'>

# %%
sns.barplot(data=df_cluster_mean, x=df_cluster_mean.index, y="numdor")
# Out:
# <Axes: ylabel='numdor'>

# %%
 sns.barplot(data=df_cluster_mean, x=df_cluster_mean.index, y="Precio")
plt.text(x=-0.13, y=82500000, s="81900570")
plt.text(x=0.9, y=42000000, s="41667250")
ax = plt.gca()
ax.ticklabel_format(style="plain", axis="y")
